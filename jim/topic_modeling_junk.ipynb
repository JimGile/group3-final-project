# %%
#! conda install spacy
#python -m spacy download en_core_web_sm

# %%
# Import the dependencies
import re 
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
# Set the maximum column width to 200. 
pd.set_option('max_colwidth', 200)

# Import spacy library
import spacy
# Load the small English language model for spacy
nlp = spacy.load("en_core_web_sm")

# %%
# Read the bbc_news_articles.csv file into a DataFrame.
d4_emails_df = pd.read_csv('../resources/scrubbed_data.csv')
# Display the first 20 rows. 
d4_emails_df.head()
# Out:
#       name                  affected_address      email_address  case_number  \
# 0      Ron          6864 East Bucknell Place      ron@email.com            0
# 1    Renee  Dahlia & High Line intersection     renee@email.com            0
# 2       JW         Happy Canyon & Jasmine St       jw@email.com            0
# 3    Clara                 Hutchinson Hills     clara@email.com      9578014
# 4  Pauline                               NaN  pauline@email.com            0
#
#          date  \
# 0  2024-08-05
# 1  2024-08-19
# 2  2024-08-19
# 3  2024-08-20
# 4  2024-08-21
#
#                                                                                                                                                                                        constituent_email_1  \
# 0  The lack of police presence and code enforcement is sending a growing message that these violations are not important…and that reckless behavior is not of great concern. Second item: affordable de...
# 1  I would like to know if there is a possible to put a yellow flashing pedestrian light on Dahlia and the intersection of the Highline Canal.. Also is there aywya that a turn signal could be impleme...
# 2  Accident took place at Happy Canyon & Jasmine. Last week an extremely careless driver drove at a high rate of speed and got stuck on the median island. Took out a tree, dug big holes in the ground...
# 3  Has many concerns about getting a compost cart, had many issues with Solid Waste and the person they were talking to. Been trying to get a compost cart for 2 years since moving into their house. N...
# 4  At any rate my concern is how will HOA condo units be charges? $150.00 per unit per year so a 200 unit building would pay $40,000 additional on storm water bill.  I look forward to clarification o...
#
#                                                                                                                                                                                              d4_response_1  \
# 0  Good morning Ron, \n\nThank you for reaching out, and I apologize for the delayed response. Council Pro Tem Romero Campbell maintains regular communication with DPD District 3, which serves Southe...
# 1  Thank you for reaching out to our office.  The area engineers have looked at this intersection where the High Line Canal crosses Dahlia multiple times at our request and have determined that a fla...
# 2  Good morning TJ,\n\nThank you for reaching out to our office and for bringing this to our attention. I have reported this to the city via 311 and it will be directed to the parks and recreation te...
# 3  Thank you for reaching out to our office and for your thoughtful email.  I hope I can touch on all your points in my response.\nUnfortunately, it is not possible for you to pick up a compost bin. ...
# 4  Good afternoon Pauline, \n\nThank you for reaching out to our office. As you know the sidewalk fee in November 2022, a citizen-led ballot initiative passed by voters directed Denver's Department o...
#
#   d4_staff_member  \
# 0          Staff1
# 1          Staff2
# 2          Staff1
# 3          Staff2
# 4          Staff1
#
#                                                                                                                              constituent_email_2  \
# 0                                                                                                                                            NaN
# 1                                                                                                                                            NaN
# 2                                                                                                                                            NaN
# 3  Clara sent another email back with more questions about how to volunteer, wants a new rec center, and still wants more info on compost cart.
# 4                                                                                                                                            NaN
#
#                                                                 d4_response_2
# 0                                                                         NaN
# 1                                                                         NaN
# 2                                                                         NaN
# 3  Did not respond as they were the same questions I had answewred previously
# 4                                                                         NaN

# %% [markdown]
# ## Preprocessing

# %%
# Check for null values.
d4_emails_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 57 non-null     object
#  1   affected_address     40 non-null     object
#  2   email_address        57 non-null     object
#  3   case_number          57 non-null     int64
#  4   date                 57 non-null     object
#  5   constituent_email_1  57 non-null     object
#  6   d4_response_1        57 non-null     object
#  7   d4_staff_member      57 non-null     object
#  8   constituent_email_2  11 non-null     object
#  9   d4_response_2        12 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 4.6+ KB

# %%
# Use Parts of Speech (POS) tagging to extract the nouns, adjectives, and verbs from the constituent_email_1 column.

# Create a function that takes a string and returns only the nouns and verbs.
def get_nouns_adjs_verbs(text: str) -> str:
    tokens = nlp(text)
    nouns_adjs_verbs = ' '.join([token.text for token in tokens if token.pos_ == "NOUN" or token.pos_ == "ADJ" or token.pos_ == "VERB"])
    unique = set(nouns_adjs_verbs.lower().split())
    return ' '.join(unique)
    
d4_emails_df['nouns_adjs_verbs'] = d4_emails_df['constituent_email_1'].apply(get_nouns_adjs_verbs)
d4_emails_df['nouns_adjs_verbs']
# Out:
# 0          sending concern affordable second item police great enforcement lack tax message wanting more denver violations behavior set important accomplish code goals presence reckless growing information
# 1                                                                                                       put pedestrian light is aywya signal implemented intersection turn like flashing yellow possible know
# 2     place got removal speed road report various spilled driver fluids person stuff big stuck escape week holes island is dug city truck took inform drove oversaw last imagine high ground trying fixes ...
# 3                                                                                                needs get compost many issues person house years has talking concerns message cart moving had getting trying
# 4     have general be unit units wage concern year budgets clarification inflation tax rules condo losing building lookup possible class made mentioned end scoop new middle regs folks bill tool fee pay ...
# 5     proposed place resident actions enjoy talking support appears second loved suck hear make effort former traffic many contradiction exacerbate revitalize environment years shooting worse specifics ...
# 6     checkmark racing predecessor done playground great table specialty wonderful homeless mayor street councilwoman nice think legacy remembrance hit time upgrades good spoken permanent addressed proj...
# 7     have spread worked attached email units pest room wife kill old bait year none pictures bombs bug health help multiple basis mean keep affect traps today roaches spray complex seen said problem kn...
# 8                                                                                                                                                                look taxes asking sidewalk email copied tool
# 9                                                                                                                                                                    billing asking incorrect meeting discuss
# 10                                                                                                                                                                  racing attached email talking road second
# 11                                                                              say wife feel car children police ask continue citizen tax safe assistance paying do stop need imagine line feet park deserve
# 12                                                                                                                                                                         cement intersection concern plants
# 13                                                                              had development is same yesterday stumped garbage do top members compel better said oriented upkeep community transit cleanup
# 14    several streets civil milled noticed professional wrong renewed mean engineer many today degree money replacing signs repaved come replacement mot opinion replaced due pavement need area waste eng...
# 15                                                                                                                                                                         increased support police vigilance
# 16                                                                                                                                      garage hoa increased condemned residents enough parking issues having
# 17                                    several gang reports tell done was venezuelan situation activity mitigate street times complex safe mailbox corner area months concerned carjacking broken dark driving
# 18                                                       have racing loud going shut quiet used problem white sleep middle killed play night bystander noise serious motorcycles innocent neighborhood window
# 19                                                                     have proposed sidewalk ordinance wastewater trash fees vetted accurate express concerns information delay increases amendments writing
# 20    situation little perception traffic district severe clean laws seems city funding significant actual ensure frustrated enough resource have racing happening done reason doing car police consequenc...
# 21                                                  have get surrounding walkable reaching used fixed houses communities closed location cracked plastic damage drive cars different slides park neighborhood
# 22                                                                                                                                                                                      loud large gatherings
# 23    worked unit lot provide was housing year built make measures are multiple lack street years property sure authorities complex - other grounds confirmed part city send apartments multi corrected ne...
# 24    pedestrian weekend place planning reopen increased lights told crossing light safety congested catch few become unsafe install plan bus stop apartments area take see blinking minutes address use e...
# 53                                                   foolish lanes account closing worried going things mess are congested used money thank city forcing people cover hide bike penny spent give cars secrets
# 54    thoughts get disheartening 's fit existing tends served regarding pool hear great former public hope many lack businesses converting indoor finds message community crowded center benefit gym locat...
# 55    happening attached unsuccessful drop unwanted receive artery live north help adjoining traffic primary businesses today worse tax article happens city opposed revenues stop debacle attempt improve...
# 56    pedestrian lanes get fix sense frustration support budget side national applied blocks parked leadership trash dollars curb used upkeep said picked transportation mentioned total service dictates ...
# Name: nouns_adjs_verbs, dtype: object

# %%
topic_dict = {
    'homeless': 'Homeless',
    'shelter': 'Homeless',
    'graffiti': 'Graffiti',
    'paint': 'Graffiti',
    'pothole': 'Pothole',
    'holes': 'Pothole',
    'animal': 'Animal',
    'pest': 'Animal',
    'weeds': 'Vegitation',
    'trees': 'Vegitation',
    'overgrown': 'Vegitation',
    'neighborhood': 'Neighborhood',
    'hoa': 'Neighborhood',
    'rno': 'Neighborhood',
    'sidewalk': 'Neighborhood',
    'sidewalks': 'Neighborhood',
    'fence': 'Neighborhood',
    'fences': 'Neighborhood',
    'snow': 'Snow Removal',
    'ice': 'Snow Removal',
    'plows': 'Snow Removal',
    'vehicle': 'Vehicle',
    'vehicles': 'Vehicle',
    'car': 'Vehicle',
    'cars': 'Vehicle',
    'motorcycle': 'Vehicle',
    'motorcycles': 'Vehicle',
    'parking': 'Parking',
    'police': 'Police',
    'gang': 'Police',
    'loud': 'Police',
    'drugs': 'Police',
    'crime': 'Police',
    'firework': 'Fireworks',
    'dumping': 'Dumping',
    'trash': 'Trash',
    'garbage': 'Trash',
    'compost': 'Trash',
    'recycling': 'Trash',
    'rent': 'Housing',
    'rental': 'Housing',
    'rentals': 'Housing',
    'apartment': 'Housing',
    'apartments': 'Housing',
    'policy': 'Policy',
    'tax': 'Policy',
    'taxes': 'Policy',
    'mayor': 'Policy',
    'council': 'Policy',
    'environmental': 'Policy',
    'environment': 'Policy',
    'rezoning': 'Policy',
    'rezone': 'Policy',
    'government': 'Policy',
    'racing': 'Street Racing',
    'transit': 'Transit',
    'traffic': 'Transit',
    'pedestrian': 'Transit',
    'intersection': 'Transit',
    'bicycle': 'Transit',
    'bike': 'Transit',
    'speed': 'Transit',
    'pavement': 'Transit',
    'parks': 'Parks',
    'park': 'Parks',
    'playground': 'Parks',
    'trails': 'Parks',
    'pool': 'Parks',
    'gym': 'Parks',
}

# Function to check if any key in dict is in the string
def check_topics(value, topic_dict):
    topics_set = set()
    for key in topic_dict:
        words = value.split()
        if key in words:
            topics_set.add(topic_dict[key])
    
    if len(topics_set) > 0:
        return ','.join(topics_set)
    return 'Other'

# Apply the function and create a new column
d4_emails_df['topics'] = d4_emails_df['nouns_adjs_verbs'].apply(lambda x: check_topics(x, topic_dict))
d4_emails_df.head()
# Out:
#       name                  affected_address      email_address  case_number  \
# 0      Ron          6864 East Bucknell Place      ron@email.com            0
# 1    Renee  Dahlia & High Line intersection     renee@email.com            0
# 2       JW         Happy Canyon & Jasmine St       jw@email.com            0
# 3    Clara                 Hutchinson Hills     clara@email.com      9578014
# 4  Pauline                               NaN  pauline@email.com            0
#
#          date  \
# 0  2024-08-05
# 1  2024-08-19
# 2  2024-08-19
# 3  2024-08-20
# 4  2024-08-21
#
#                                                                                                                                                                                        constituent_email_1  \
# 0  The lack of police presence and code enforcement is sending a growing message that these violations are not important…and that reckless behavior is not of great concern. Second item: affordable de...
# 1  I would like to know if there is a possible to put a yellow flashing pedestrian light on Dahlia and the intersection of the Highline Canal.. Also is there aywya that a turn signal could be impleme...
# 2  Accident took place at Happy Canyon & Jasmine. Last week an extremely careless driver drove at a high rate of speed and got stuck on the median island. Took out a tree, dug big holes in the ground...
# 3  Has many concerns about getting a compost cart, had many issues with Solid Waste and the person they were talking to. Been trying to get a compost cart for 2 years since moving into their house. N...
# 4  At any rate my concern is how will HOA condo units be charges? $150.00 per unit per year so a 200 unit building would pay $40,000 additional on storm water bill.  I look forward to clarification o...
#
#                                                                                                                                                                                              d4_response_1  \
# 0  Good morning Ron, \n\nThank you for reaching out, and I apologize for the delayed response. Council Pro Tem Romero Campbell maintains regular communication with DPD District 3, which serves Southe...
# 1  Thank you for reaching out to our office.  The area engineers have looked at this intersection where the High Line Canal crosses Dahlia multiple times at our request and have determined that a fla...
# 2  Good morning TJ,\n\nThank you for reaching out to our office and for bringing this to our attention. I have reported this to the city via 311 and it will be directed to the parks and recreation te...
# 3  Thank you for reaching out to our office and for your thoughtful email.  I hope I can touch on all your points in my response.\nUnfortunately, it is not possible for you to pick up a compost bin. ...
# 4  Good afternoon Pauline, \n\nThank you for reaching out to our office. As you know the sidewalk fee in November 2022, a citizen-led ballot initiative passed by voters directed Denver's Department o...
#
#   d4_staff_member  \
# 0          Staff1
# 1          Staff2
# 2          Staff1
# 3          Staff2
# 4          Staff1
#
#                                                                                                                              constituent_email_2  \
# 0                                                                                                                                            NaN
# 1                                                                                                                                            NaN
# 2                                                                                                                                            NaN
# 3  Clara sent another email back with more questions about how to volunteer, wants a new rec center, and still wants more info on compost cart.
# 4                                                                                                                                            NaN
#
#                                                                 d4_response_2  \
# 0                                                                         NaN
# 1                                                                         NaN
# 2                                                                         NaN
# 3  Did not respond as they were the same questions I had answewred previously
# 4                                                                         NaN
#
#                                                                                                                                                                                           nouns_adjs_verbs  \
# 0       sending concern affordable second item police great enforcement lack tax message wanting more denver violations behavior set important accomplish code goals presence reckless growing information
# 1                                                                                                    put pedestrian light is aywya signal implemented intersection turn like flashing yellow possible know
# 2  place got removal speed road report various spilled driver fluids person stuff big stuck escape week holes island is dug city truck took inform drove oversaw last imagine high ground trying fixes ...
# 3                                                                                             needs get compost many issues person house years has talking concerns message cart moving had getting trying
# 4  have general be unit units wage concern year budgets clarification inflation tax rules condo losing building lookup possible class made mentioned end scoop new middle regs folks bill tool fee pay ...
#
#                 topics
# 0        Police,Policy
# 1              Transit
# 2      Pothole,Transit
# 3                Trash
# 4  Neighborhood,Policy

# %%
# Remove numbers and non-alphabetic characters from the constituent_email_1 column.
d4_topic_df['constituent_email_1'] = d4_emails_df['constituent_email_1'].apply(lambda x: re.sub(r'[^a-zA-Z\s ]', '', str(x)))
d4_topic_df['constituent_email_1']
# Out:
# 0          sending concern affordable second item police great enforcement lack tax message wanting more denver violations behavior set important accomplish code goals presence reckless growing information
# 32                                                                           busy re mean many smashed beautiful yard ride said looks sooooo do added months take see junk contacted cars junked neighborhood
# 33    have racing streets leak frame bicycle communication cycles watered things including police grass trash street dropped towers more thank fixed other happy protection surveillance greening area mot...
# 34    have size get pick compost receive recycle find quarterly help issues trash decrease assumption barrels barrel ordered learned credit week end discard happy hoping bill site small charged based in...
# 35                                                                             have direct buildings sidewalk waste condos bill hoa involved address receives property complex comes condo access split water
# 36                                                                              information ownership home rentals tell lack done units affordable number housing year advance last increase concerned thanks
# 37                                                                                                        include have home own businesses collect based rental property owners money addressed rentals homes
# 38                                                                       heard jt oppressive eft news policies call government result catch clipl rule has opinion letters radio people reporting had station
# 39    heard resident official contained existing fence reduce proposal regarding buffer contact notification received office property understand building house is rezoning maintaining space important sh...
# 40    have left done span happen internet apple provide oversee regarding scheduled options winds reached wire work contact stuff fronts office yard clue unclear problem talk wired company service taken...
# 41    happening son lines httpswwwknightscopecomusecasespublicpark lot modernize frequent recommend brings parking old concerns year dear children portrait safety offers diverse company bring clip is fa...
# 42    have demonstrate facility campaign reason spot participate suggest necessary opening live contributive shelter ill speak goodwill hope many day district contact inaugural remain crucial working bu...
# 43                                      website limited get proposed lot live notice received years working plan thank sad rezoning do m vague online concerned info status tried much elaborate s park empty
# 44    have resident done attracts unoccupied lost change most inconvenient businesses continue years food corridor disheartened rapid know week more makes crime assistance bank longtime native fast m cl...
# 45    get pass going concern road amount turn live make multiple traffic day safer express times highway other happens do dangerous killed corner need time writing speeding see using driving cars lane n...
# 46    lanes get plows riders careful advance little becomes vast clearing work presume appropriate behavior seems seem accomplish time meet ice turning frustrated utility others reduced return tended fo...
# 47                                                get breaking combing car things handle wish mayor street governor know week occurred stole homes doors control need neighbors open break video neighborhood
# 48    left begins tell matter density trail next camp hard fear amount garbage feel regarding believe expect belongings including police canal mess covered hear home hope homeless walk trash unsightly t...
# 49    have lot campaign session feel organizer initiatives year welfare visit measures meeting voted hope answer volunteer ballot weather decided  buzz more other delight engaged citizens regular rnos c...
# 50                 have streets counsel going doing seeing many sits living more drugs saddened die jail city bus mandatory killing stand need allows pay people want rehabilitation drug state demand ticket
# 51                                                                                                                               concrete sidewalk weeds thank tell contact south jurisdiction side crumbling
# 52    individuals non honk done concern hard was young told emergency police shelter multiple response safety work day answer contribute street express became sure go yelling  first community know washe...
# 53                                                   foolish lanes account closing worried going things mess are congested used money thank city forcing people cover hide bike penny spent give cars secrets
# 54    thoughts get disheartening s fit existing tends served regarding pool hear great former public hope many lack businesses converting indoor finds message community crowded center benefit gym locati...
# 55    happening attached unsuccessful drop unwanted receive artery live north help adjoining traffic primary businesses today worse tax article happens city opposed revenues stop debacle attempt improve...
# 56    pedestrian lanes get fix sense frustration support budget side national applied blocks parked leadership trash dollars curb used upkeep said picked transportation mentioned total service dictates ...
# Name: constituent_email_1, dtype: object

# %% [markdown]
# ## Process the Text to Tokens and Counts.

# %%
# Create an instance of the CountVectorizer and set the max_df to 0.95 and min_df to 5, and use the "english" stopwords.
cv = CountVectorizer(max_df=0.95, min_df=3, stop_words='english')
cv
# Out:
# CountVectorizer(max_df=0.95, min_df=3, stop_words='english')

# %%
# Transform each row from the news_summary to a DTM.
dtm = cv.fit_transform(d4_topic_df['constituent_email_1'])
# Get the shape of the DTM.
print(dtm.shape)
# Out:
# (57, 147)

# %% [markdown]
# ## LDA

# %%
# Create and instance of the LatentDirichletAllocation() class with 5 topics.
LDA = LatentDirichletAllocation(n_components=15,random_state=42)
# Fit the model with our DTM data.
LDA_data = LDA.fit(dtm)
# Check the length of the vocabulary 
len(cv.get_feature_names_out())
# Out:
# 147

# %% [markdown]
# ## Get the Top 15 Words Per Topic

# %%
# Print the top 15 words for each topic.
for index,topic in enumerate(LDA.components_):
    print(f'The Top 10 Words For Topic #{index+1}')
    print([cv.get_feature_names_out()[i] for i in topic.argsort()[-15:]])
    print('\n')
# Out:
# The Top 10 Words For Topic #1
# ['residents', 'having', 'parking', 'car', 'mayor', 'things', 'neighbors', 'know', 'issues', 'increased', 'week', 'need', 'hoa', 'neighborhood', 'street']
#
#
# The Top 10 Words For Topic #2
# ['situation', 'information', 'little', 'stop', 'safe', 'better', 'years', 'police', 'nice', 'good', 'addressed', 'time', 'racing', 'getting', 'street']
#
#
# The Top 10 Words For Topic #3
# ['park', 'thank', 'years', 'issues', 'information', 'intersection', 'street', 'look', 'email', 'going', 'police', 'neighborhood', 'concern', 'property', 'sidewalk']
#
#
# The Top 10 Words For Topic #4
# ['new', 'multiple', 'going', 'lane', 'safer', 'planning', 'help', 'complex', 'writing', 'said', 'live', 'corner', 'driving', 'concerned', 'need']
#
#
# The Top 10 Words For Topic #5
# ['appreciate', 'better', 'turn', 'thank', 'intersection', 'message', 'second', 'cross', 'lack', 'great', 'regarding', 'like', 'idea', 'community', 'use']
#
#
# The Top 10 Words For Topic #6
# ['lanes', 'concerned', 'noticed', 'mean', 'today', 'congested', 'home', 'streets', 'sidewalk', 'going', 'information', 'look', 'money', 'tell', 'thank']
#
#
# The Top 10 Words For Topic #7
# ['removed', 'times', 'homeless', 'tell', 'appreciated', 'safe', 'address', 'home', 'possible', 'know', 'pedestrian', 'trash', 'light', 'area', 'police']
#
#
# The Top 10 Words For Topic #8
# ['middle', 'new', 'lot', 'wanted', 'end', 'safety', 'units', 'pay', 'concerns', 'tax', 'park', 'look', 'concern', 'sidewalk', 'year']
#
#
# The Top 10 Words For Topic #9
# ['crime', 'fixed', 'parking', 'having', 'vehicles', 'mean', 'like', 'area', 'issues', 'support', 'said', 'ride', 'cars', 'used', 'neighborhood']
#
#
# The Top 10 Words For Topic #10
# ['second', 'place', 'corner', 'make', 'hear', 'traffic', 'issue', 'going', 'support', 'people', 'area', 'safe', 'years', 'proposed', 'problem']
#
#
# The Top 10 Words For Topic #11
# ['racing', 'place', 'message', 'week', 'issues', 'tree', 'getting', 'attached', 'needs', 'concerns', 'years', 'email', 'talking', 'road', 'trying']
#
#
# The Top 10 Words For Topic #12
# ['south', 'attached', 'needs', 'provide', 'going', 'street', 'years', 'help', 'businesses', 'complex', 'property', 'live', 'lot', 'city', 'issues']
#
#
# The Top 10 Words For Topic #13
# ['work', 'taken', 'need', 'issue', 'removed', 'tree', 'week', 'getting', 'provide', 'needs', 'years', 'businesses', 'address', 'months', 'neighborhood']
#
#
# The Top 10 Words For Topic #14
# ['reason', 'area', 'contacted', 'months', 'time', 'day', 'received', 'community', 'property', 'people', 'building', 'feel', 'heard', 'hope', 'contact']
#
#
# The Top 10 Words For Topic #15
# ['trash', 'safety', 'appreciate', 'answer', 'bus', 'people', 'police', 'line', 'know', 'express', 'received', 'sidewalk', 'city', 'doing', 'way']

# %% [markdown]
# ### **Question:** What is the label for each topic?
# ---
# - TOPIC 1: Entertainment
# - TOPIC 2: Sports
# - TOPIC 3: Business
# - TOPIC 4: Politics
# - TOPIC 5: Technology

# %% [markdown]
# ## Assign the Topics and Labels to the News Summaries

# %%
# Transform our DTM so we get an array with the (number_of_documents, number_of_topics).
topic_results = LDA.transform(dtm)

# Get the shape of the topic results
topic_results.shape
# Out:
# (57, 5)

# %%
# Read the bbc_news_articles.csv file into a DataFrame.
d4_emails_df = pd.read_csv('../resources/scrubbed_data.csv')
# Display the DataFrame. 
d4_emails_df.head()
# Out:
#       name                  affected_address      email_address  case_number  \
# 0      Ron          6864 East Bucknell Place      ron@email.com            0
# 1    Renee  Dahlia & High Line intersection     renee@email.com            0
# 2       JW         Happy Canyon & Jasmine St       jw@email.com            0
# 3    Clara                 Hutchinson Hills     clara@email.com      9578014
# 4  Pauline                               NaN  pauline@email.com            0
#
#          date  \
# 0  2024-08-05
# 1  2024-08-19
# 2  2024-08-19
# 3  2024-08-20
# 4  2024-08-21
#
#                                                                                                                                                                                        constituent_email_1  \
# 0  The lack of police presence and code enforcement is sending a growing message that these violations are not important…and that reckless behavior is not of great concern. Second item: affordable de...
# 1  I would like to know if there is a possible to put a yellow flashing pedestrian light on Dahlia and the intersection of the Highline Canal.. Also is there aywya that a turn signal could be impleme...
# 2  Accident took place at Happy Canyon & Jasmine. Last week an extremely careless driver drove at a high rate of speed and got stuck on the median island. Took out a tree, dug big holes in the ground...
# 3  Has many concerns about getting a compost cart, had many issues with Solid Waste and the person they were talking to. Been trying to get a compost cart for 2 years since moving into their house. N...
# 4  At any rate my concern is how will HOA condo units be charges? $150.00 per unit per year so a 200 unit building would pay $40,000 additional on storm water bill.  I look forward to clarification o...
#
#                                                                                                                                                                                              d4_response_1  \
# 0  Good morning Ron, \n\nThank you for reaching out, and I apologize for the delayed response. Council Pro Tem Romero Campbell maintains regular communication with DPD District 3, which serves Southe...
# 1  Thank you for reaching out to our office.  The area engineers have looked at this intersection where the High Line Canal crosses Dahlia multiple times at our request and have determined that a fla...
# 2  Good morning TJ,\n\nThank you for reaching out to our office and for bringing this to our attention. I have reported this to the city via 311 and it will be directed to the parks and recreation te...
# 3  Thank you for reaching out to our office and for your thoughtful email.  I hope I can touch on all your points in my response.\nUnfortunately, it is not possible for you to pick up a compost bin. ...
# 4  Good afternoon Pauline, \n\nThank you for reaching out to our office. As you know the sidewalk fee in November 2022, a citizen-led ballot initiative passed by voters directed Denver's Department o...
#
#   d4_staff_member  \
# 0          Staff1
# 1          Staff2
# 2          Staff1
# 3          Staff2
# 4          Staff1
#
#                                                                                                                              constituent_email_2  \
# 0                                                                                                                                            NaN
# 1                                                                                                                                            NaN
# 2                                                                                                                                            NaN
# 3  Clara sent another email back with more questions about how to volunteer, wants a new rec center, and still wants more info on compost cart.
# 4                                                                                                                                            NaN
#
#                                                                 d4_response_2
# 0                                                                         NaN
# 1                                                                         NaN
# 2                                                                         NaN
# 3  Did not respond as they were the same questions I had answewred previously
# 4                                                                         NaN

# %%
# Use the add_topic_labels function to add the topic and topic label to each news summary. 
# Dictionary of  topics and topic label.
topic_labels = {
    1: 'Traffic,Trees',
    2: 'Homeless',
    3: 'Street Racing',
    4: 'Parking,Parks',
    5: 'Trash,Parks'
}

# Define the function and pass in the DataFrame, the topic_results, and topic_labels dictionary.
def add_topic_labels(df, topic_results, topic_labels):
    # Find the dominant topic for each document and add the label to a new column
    df['topic'] = topic_results.argmax(axis=1) + 1
    # Use the map function to add the topic label to the news summary based on the topic number.
    df['topic_label'] = df['topic'].map(topic_labels)

# %%
# Call the function to add topic labels to your DataFrame.
add_topic_labels(d4_emails_df, topic_results, topic_labels)

# %%
# Display the first 20 rows of the updated DataFrame. 
d4_emails_df.head(20)
# Out:
#         name                  affected_address       email_address  \
# 0        Ron          6864 East Bucknell Place       ron@email.com
# 1      Renee  Dahlia & High Line intersection      renee@email.com
# 2         JW         Happy Canyon & Jasmine St        jw@email.com
# 3      Clara                 Hutchinson Hills      clara@email.com
# 4    Pauline                               NaN   pauline@email.com
# 5     Debbie          4504 S Yosemite St #361     debbie@email.com
# 6   Michelle                               NaN  michelle@email.com
# 7     Joshua                   Hampden Heights    joshua@email.com
# 8      Bruce                 Hutchinson Hills      bruce@email.com
# 9      Janet                               NaN     janet@email.com
# 10     Colin            8100 E Union Ave #2006     colin@email.com
# 11    Daniel                               NaN    daniel@email.com
# 12   Kenneth  Quincy and DTC/Tamarac to Monaco   kenneth@email.com
# 13      Jody                Cameron Apartments      jody@email.com
# 14     David                 3193 S Wilding Ct     david@email.com
# 15      Alan          2609 S Quebec St Unit 21      alan@email.com
# 16      Andy                  3390 S Ulster Ct      andy@email.com
# 17      Judy                  2609 S Quebec St      judy@email.com
# 18     Scott               3202 S Josephine St     scott@email.com
# 19     Brian                               NaN     brian@email.com
#
#     case_number        date  \
# 0             0  2024-08-05
# 1             0  2024-08-19
# 2             0  2024-08-19
# 3       9578014  2024-08-20
# 4             0  2024-08-21
# 5             0  2024-08-21
# 6             0  2024-08-25
# 7             0  2024-08-26
# 8             0  2024-08-27
# 9             0  2024-08-28
# 10            0  2024-08-31
# 11            0  2024-09-01
# 12            0  2024-08-28
# 13            0  2024-09-03
# 14            0  2024-09-04
# 15            0  2024-09-05
# 16            0  2024-08-30
# 17            0  2024-09-05
# 18            0  2024-09-06
# 19            0  2024-09-08
#
#                                                                                                                                                                                         constituent_email_1  \
# 0   The lack of police presence and code enforcement is sending a growing message that these violations are not important…and that reckless behavior is not of great concern. Second item: affordable de...
# 1   I would like to know if there is a possible to put a yellow flashing pedestrian light on Dahlia and the intersection of the Highline Canal.. Also is there aywya that a turn signal could be impleme...
# 2   Accident took place at Happy Canyon & Jasmine. Last week an extremely careless driver drove at a high rate of speed and got stuck on the median island. Took out a tree, dug big holes in the ground...
# 3   Has many concerns about getting a compost cart, had many issues with Solid Waste and the person they were talking to. Been trying to get a compost cart for 2 years since moving into their house. N...
# 9   Thank you for your patience while our office was getting ready for, hosting, and wrapping up our annual community festival, South by Southeast.  We are back to regular office hours and would love ...
# 10                                                                   I forwarded this to Matt Grimsley to see if he ould give us an update on enforcement and how to report.  I did not respond to him yet.
# 11  I have highlighted the Denver parking ordinances concerning campers and vehicles under 22 feet in length below.  Please continue to report campers and vehicles to 311 when they are in violation of...
# 12  Laura Wigger & Ted Berg both responded: (Ted on 9/3) The Hawthorns that are dead are very small trees, the likelihood of failure is improbable and the likelihood of them impacting a target is very...
# 13  We just went over there to look at the property.  Yes, there is litter but not to the extent that the city would site the property owner for.  The same goes for the tree and yard debris, it does n...
# 14                                                                             I forwarded response from Brian R DOTI.  It was lenghty to I filed it under paving if you need to find the response again.
# 15  Good afternoon Alan and Vicki, \n\nThank you for reaching out to our office and for your advocacy. Our office will continue to support DPD district 3 with all efforts to continue to make the City ...
# 16  Thanks you for reaching out to our office and sharing your concern for your neighbors whose parking garage has been closed do to structural problems.  I know that it is a frustrating situation for...
# 17  Good morning Judy,\n\nThank you so much for reaching out to our office. We’ve been in close communication with the Denver Police Department (DPD) District 3, and they have informed us that there a...
# 18                                                                                                                                                                                                responded
# 19  Good morning Brian,\n\nThank you for reaching out to our office. The sidewalk fee amendment is a proposed ordinance our office is keeping a close eye on. The department of Transportation and Infra...
#
#    d4_staff_member  \
# 0           Staff1
# 1           Staff2
# 2           Staff1
# 3           Staff2
# 4           Staff1
# 5           Staff2
# 6           Staff2
# 7           Staff1
# 8           Staff1
# 9           Staff1
# 10          Staff2
# 11          Staff2
# 12          Staff2
# 13          Staff2
# 14          Staff2
# 15          Staff1
# 16          Staff2
# 17          Staff1
# 18          Staff2
# 19          Staff1
#
#                                                                                                                                                                                         constituent_email_2  \
# 0                                                                                                                                                                                                       NaN
# 1                                                                                                                                                                                                       NaN
# 2                                                                                                                                                                                                       NaN
# 3                                                             Clara sent another email back with more questions about how to volunteer, wants a new rec center, and still wants more info on compost cart.
# 4                                                                                                                                                                                                       NaN
# 5                                                                                                                                                                                                       NaN
# 6                                                                                                                                                                                                       NaN
# 7   Thank you for following back up with me about my email concerning the bugs. Sorry for not following up and emailing right away in return. We had put in pest control with our apartment complex and ...
# 8                                                                                                                                                                                                       NaN
# 9                                                                                                                                                                                                       NaN
# 10  Thank you for the reply. \nAttached are a picture and a video from last night - Sept 5, 2024 - from around 10 to 11:30PM. The picture shows the road racers congregating on the roof of the garage a...
# 11  Thanks so much for taking the time to respond after a full month and completely disregarding the message above. Not once did you speak on the issue I brought up, only side stepping the questions a...
# 12                                                                                                                                                                                                      NaN
# 13                                                                                                                                                                                                      NaN
# 14                                                                                                                                                                                                      NaN
# 15                                                                                                                                                                                                      NaN
# 16                                                                                                                                                                                                      NaN
# 17                                                                                                                                                                                                      NaN
# 18                                                                                                                                                                                                      NaN
# 19                                                                                                                                                                                                      NaN
#
#                                                                                                                                                                                               d4_response_2  \
# 0                                                                                                                                                                                                       NaN
# 1                                                                                                                                                                                                       NaN
# 2                                                                                                                                                                                                       NaN
# 3                                                                                                                                Did not respond as they were the same questions I had answewred previously
# 4                                                                                                                                                                                                       NaN
# 5                                                                                                                                                                                                       NaN
# 6                                                                                                                                                                                                       NaN
# 7   Thank you Joshua for the additional details. I\nhave also submitted a report through 311. \nThe case will be redirected to the appropriate agency for \nintervention. Do not be alarmed when you rec...
# 8                                                                                                                                                                                                       NaN
# 9                                                                                                                                                                                                       NaN
# 10  Thank you for bringing this to our attention.  I have heard from our contact at the Denver Police Department and, the property owner on DTC reached out to them about this group. The group defeated...
# 11                                                                                I did not respond but I forwarded his email to the SET team but told them I would connect them when it seemed approriate.
# 12                                                                                                                                                                                                      NaN
# 13                                                                                                                                                                                                      NaN
# 14                                                                                                                                                                                                      NaN
# 15                                                                                                                                                                                                      NaN
# 16                                                                                                                                                                                                      NaN
# 17                                                                                                                                                                                                      NaN
# 18                                                                                                                                                                                                      NaN
# 19                                                                                                                                                                                                      NaN
#
#     topic    topic_label
# 0       3  Street Racing
# 1       1  Traffic,Trees
# 2       1  Traffic,Trees
# 3       1  Traffic,Trees
# 4       2       Homeless
# 5       5    Trash,Parks
# 6       2       Homeless
# 7       2       Homeless
# 8       3  Street Racing
# 9       1  Traffic,Trees
# 10      3  Street Racing
# 11      5    Trash,Parks
# 12      1  Traffic,Trees
# 13      3  Street Racing
# 14      2       Homeless
# 15      5    Trash,Parks
# 16      4  Parking,Parks
# 17      3  Street Racing
# 18      5    Trash,Parks
# 19      5    Trash,Parks

# %%
# Display the last 20 rows of the updated DataFrame.
d4_emails_df.tail(10)
# Out:
#                                                                                                                                                                                                  news_summary  \
# 2215  The new book claims Mr Prescott hosted a dinner in November 2003 where the prime minister told Mr Brown he would stand down before the next election because he had lost trust over the Iraq war.Mr ...
# 2216  Actor Daniel Day-Lewis is to be presented with an award for his career in film at the Berlin Film Festival.Day-Lewis has competed four times at the Berlin Film Festival, with films In The Name Of ...
# 2217  With so much time spent in the spotlight, Holmes has increasingly dropped hints that her ambition on the track has begun to wilt.Four months later, Holmes stormed to double Olympic gold and has si...
# 2218  US oil prices have fallen by 6%, driven down by forecasts of a mild winter in the densely populated northeast.Statistics released last week showed that stockpiles of oil products in the US had ris...
# 2219  Instead, said Mr Doctorow, DRM systems were intended to control the group that electronics firms have most hold over - consumers.By setting up the alliance to work on a common control system, the ...
# 2220  The Votes at 16 alliance said it was a good thing to "engage people" by lowering the candidacy age but argued lowering the voting age would be much more effective.That is because the age of majori...
# 2221  West Ham boss Alan Pardew said: "It's a shame because I thought there was good English banter in the crowd.The FA is to take action after trouble marred Wednesday's Carling Cup tie between Chelsea...
# 2222  Navratilova, who made a comeback after retiring in 1994, will play doubles and mixed doubles events in 2005.I'm still that good."Navratilova has won three Grand Slam mixed doubles titles since she...
# 2223  "You would think they would have been available in December as it can take two months for the body to respond."The first chance we will get to do that is at the players meeting on the Saturday bef...
# 2224  Other than its warning on possible tax hikes, the NIESR report was optimistic about the state of the UK and global economy.The UK government will have to raise taxes or rein in spending if it want...
#
#       topic    topic_label
# 2215      4       Politics
# 2216      1  Entertainment
# 2217      2         Sports
# 2218      3       Business
# 2219      5     Technology
# 2220      4       Politics
# 2221      1  Entertainment
# 2222      2         Sports
# 2223      2         Sports
# 2224      3       Business

# %% [markdown]
# **Question:** Did LDA do a good job at assigning the appropriate topic to the news summaries?
#
# **Answer:** Yes. Most of the news summaries look like they have been appropriately assigned the correct topic and topic label.
